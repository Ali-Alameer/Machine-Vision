# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12355, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 12355 (delta 9), reused 4 (delta 1), pack-reused 12335
# Receiving objects: 100% (12355/12355), 12.18 MiB | 8.39 MiB/s, done.
# Resolving deltas: 100% (8523/8523), done.

# %%
cd yolov5
# Out:
# /home/ali/projects/python_project/YOLO/YOLO-Drowsiness-Detection-main/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib>=3.2.2
#   Using cached matplotlib-3.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
# Requirement already satisfied: numpy>=1.18.5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (1.23.0)
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: Pillow>=7.1.2 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (9.1.1)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 11.4 MB/s eta 0:00:0031m12.1 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.23.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (2.28.1)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 10.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: torch>=1.7.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (1.12.0+cu116)
# Requirement already satisfied: torchvision>=0.8.1 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.13.0+cu116)
# Collecting tqdm>=4.41.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 12.8 MB/s eta 0:00:00
# Collecting protobuf<4.21.3
#   Downloading protobuf-4.21.2-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.8/407.8 kB 11.0 MB/s eta 0:00:000:00:01
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 11.4 MB/s eta 0:00:000:00:010:00:01:01
# Collecting pandas>=1.1.4
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 11.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (8.4.0)
# Requirement already satisfied: psutil in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (5.9.1)
# Collecting thop
#   Downloading thop-0.1.0.post2206102148-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (21.3)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (3.0.9)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (3.3)
# Requirement already satisfied: typing-extensions in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 12)) (4.2.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel>=0.26 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 18)) (0.37.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 11.9 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 11.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.47.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: setuptools>=41.0.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 18)) (62.6.0)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 11.1 MB/s eta 0:00:00
# Collecting protobuf<4.21.3
#   Downloading protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.3 MB/s eta 0:00:0031m11.8 MB/s eta 0:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.9.0-py2.py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 10.9 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 11.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: pickleshare in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (3.0.30)
# Requirement already satisfied: stack-data in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (0.3.0)
# Requirement already satisfied: decorator in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (2.12.0)
# Requirement already satisfied: matplotlib-inline in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (0.1.3)
# Requirement already satisfied: backcall in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (5.3.0)
# Requirement already satisfied: pexpect>4.3 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from ipython->-r requirements.txt (line 35)) (0.18.1)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 18)) (1.16.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 35)) (0.8.3)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 35)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r requirements.txt (line 35)) (0.2.5)
# Requirement already satisfied: executing in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from stack-data->ipython->-r requirements.txt (line 35)) (0.8.3)
# Requirement already satisfied: asttokens in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from stack-data->ipython->-r requirements.txt (line 35)) (2.0.5)
# Requirement already satisfied: pure-eval in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from stack-data->ipython->-r requirements.txt (line 35)) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 18)) (3.8.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 11.1 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, pytz, pyasn1, werkzeug, tqdm, tensorboard-data-server, scipy, rsa, PyYAML, pyasn1-modules, protobuf, opencv-python, oauthlib, kiwisolver, importlib-metadata, grpcio, fonttools, cycler, cachetools, absl-py, thop, requests-oauthlib, pandas, matplotlib, markdown, google-auth, seaborn, google-auth-oauthlib, tensorboard
# Successfully installed PyYAML-6.0 absl-py-1.1.0 cachetools-5.2.0 cycler-0.11.0 fonttools-4.33.3 google-auth-2.9.0 google-auth-oauthlib-0.4.6 grpcio-1.47.0 importlib-metadata-4.12.0 kiwisolver-1.4.3 markdown-3.3.7 matplotlib-3.5.2 oauthlib-3.2.0 opencv-python-4.6.0.66 pandas-1.4.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2022.1 requests-oauthlib-1.3.1 rsa-4.8 scipy-1.8.1 seaborn-0.11.2 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 thop-0.1.0.post2206102148 tqdm-4.64.0 werkzeug-2.1.2

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/ali/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-6-30 Python-3.8.10 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = '/home/ali/projects/python_project/YOLO/YOLO-Drowsiness-Detection-main/data/images/awake.5d4a590e-f891-11ec-998f-59c589613518.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 480x640 2 persons
# Speed: 5.7ms pre-process, 842.4ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[ 71,  83,  95],
#          [ 69,  81,  93],
#          [ 69,  81,  95],
#          ...,
#          [155, 140, 135],
#          [157, 139, 135],
#          [158, 140, 136]],
#
#         [[ 72,  84,  96],
#          [ 71,  83,  95],
#          [ 71,  83,  97],
#          ...,
#          [153, 138, 133],
#          [156, 138, 134],
#          [156, 138, 134]],
#
#         [[ 74,  87,  96],
#          [ 73,  86,  95],
#          [ 73,  85,  97],
#          ...,
#          [153, 138, 131],
#          [155, 138, 131],
#          [155, 138, 131]],
#
#         ...,
#
#         [[193, 207, 208],
#          [192, 206, 207],
#          [192, 206, 207],
#          ...,
#          [ 61,  15,  15],
#          [ 59,  15,  14],
#          [ 59,  15,  14]],
#
#         [[191, 205, 206],
#          [190, 204, 205],
#          [190, 204, 205],
#          ...,
#          [ 61,  15,  15],
#          [ 59,  15,  14],
#          [ 59,  15,  14]],
#
#         [[191, 205, 206],
#          [191, 205, 206],
#          [191, 205, 206],
#          ...,
#          [ 58,  12,  12],
#          [ 58,  14,  13],
#          [ 59,  15,  14]]], dtype=uint8)]

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 cap = cv2.VideoCapture(0)
#       2 while cap.isOpened():
# ----> 3     ret, frame = cap.read()
#       5     # Make detections
#       6     results = model(frame)
#
# KeyboardInterrupt:

# %% [markdown]
# # Test a video

# %%
cap = cv2.VideoCapture('test.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(2)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# Collecting images for awake, image number 1
# Collecting images for awake, image number 2
# Collecting images for awake, image number 3
# Collecting images for awake, image number 4
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# Collecting images for drowsy, image number 1
# Collecting images for drowsy, image number 2
# Collecting images for drowsy, image number 3
# Collecting images for drowsy, image number 4

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2090, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 2090 (delta 43), reused 79 (delta 34), pack-reused 1986
# Receiving objects: 100% (2090/2090), 232.91 MiB | 7.98 MiB/s, done.
# Resolving deltas: 100% (1230/1230), done.

# %%
# GUI and its dependencies
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Requirement already satisfied: pyqt5 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (5.15.7)
# Requirement already satisfied: lxml in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (4.9.0)
# Collecting lxml
#   Downloading lxml-4.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 11.3 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from pyqt5) (12.11.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.0 in /home/ali/projects/python_project/YOLO/thisEnv/lib/python3.8/site-packages (from pyqt5) (5.15.2)
# Installing collected packages: lxml
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.0
#     Uninstalling lxml-4.9.0:
#       Successfully uninstalled lxml-4.9.0
# Successfully installed lxml-4.9.1

# %%
# Next, open label image from terminal using same environment 
# This is by going to the directory of the clonned folder and run python labelImage.py 
# Create a dataset.yaml file in yolov5 directory and copy template from the torch hub website https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data
#

# %%
# !cd yolov5 && python train.py --img 320 --batch 160 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=160, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 35 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-272-g8983324 Python-3.8.10 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7065478 parameters, 7065478 gradients
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.00125
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# train: Scanning '/home/ali/projects/python_project/YOLO/YOLO-Drowsiness-Detectio
# val: Scanning '/home/ali/projects/python_project/YOLO/YOLO-Drowsiness-Detection-
# Plotting labels to runs/train/exp2/labels.jpg...
#
# AutoAnchor: 5.10 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 500 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/499    0.573G    0.1156   0.01401   0.07446        20       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00382        0.2    0.00592    0.00167
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/499      0.6G    0.1143   0.01769   0.07586        25       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00755        0.4    0.00903    0.00284
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/499      0.6G    0.1122    0.0139   0.07538        17       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00743        0.4     0.0089    0.00284
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/499      0.6G    0.1115   0.01813   0.07382        24       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00719        0.4    0.00899    0.00298
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/499      0.6G    0.1118   0.01406   0.07285        18       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00722        0.4    0.00908    0.00325
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/499      0.6G    0.1091   0.01271   0.07417        14       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00692        0.4     0.0131    0.00372
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/499      0.6G    0.1096   0.01417   0.07092        19       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00678        0.4     0.0133    0.00416
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/499      0.6G    0.1078   0.01412   0.07399        18       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00671        0.4     0.0131    0.00455
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/499      0.6G    0.1064   0.01959    0.0728        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.00664        0.4     0.0128    0.00446
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/499      0.6G    0.1018   0.01606    0.0721        19       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10    0.
20       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.938
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    458/499      0.6G   0.01399  0.005977   0.00163        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.933
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    459/499      0.6G   0.01246  0.006893  0.001604        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.924
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    460/499      0.6G   0.01286  0.004752  0.001585        16       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.918
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    461/499      0.6G   0.01402  0.009126  0.002034        26       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.922
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    462/499      0.6G   0.01815  0.006011  0.001951        19       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.944
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    463/499      0.6G   0.01247  0.005426  0.001593        17       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.932
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    464/499      0.6G   0.01557  0.004613  0.002315        14       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.912
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    465/499      0.6G   0.01586  0.006418  0.002355        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.913
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    466/499      0.6G   0.01494  0.006021  0.001824        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.923
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    467/499      0.6G   0.01584  0.004802  0.007085        17       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.935
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    468/499      0.6G   0.01513  0.004978  0.001616        16       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.939
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    469/499      0.6G   0.01767  0.007394  0.001748        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.935
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    470/499      0.6G    0.0153  0.006771  0.002208        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.916
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    471/499      0.6G   0.01805  0.007796    0.0032        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.891
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    472/499      0.6G   0.01705  0.008746   0.00237        25       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.876
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    473/499      0.6G   0.01632  0.004532  0.001531        15       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.912
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    474/499      0.6G   0.01676  0.005987  0.001862        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.902
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    475/499      0.6G   0.01371  0.005858  0.001794        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.899
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    476/499      0.6G   0.01316   0.00699  0.001671        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.938
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    477/499      0.6G   0.01199  0.007067  0.001632        24       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.913
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    478/499      0.6G   0.01213  0.005855  0.001513        20       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.897
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    479/499      0.6G   0.01604  0.006157  0.002098        19       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.908
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    480/499      0.6G   0.01478  0.006775  0.002749        25       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.918
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    481/499      0.6G   0.01286  0.006896  0.001621        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995        0.9
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    482/499      0.6G   0.01215  0.005588  0.001591        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.903
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    483/499      0.6G   0.01131  0.005916  0.001616        20       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.902
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    484/499      0.6G   0.01265  0.006669  0.001757        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.901
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    485/499      0.6G   0.01071  0.006599  0.001566        25       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.907
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    486/499      0.6G   0.01218  0.005155   0.00205        14       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.902
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    487/499      0.6G    0.0115  0.006117  0.001758        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.902
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    488/499      0.6G   0.01212  0.006709  0.001759        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.917
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    489/499      0.6G   0.01467  0.004803  0.001454        17       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.933
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    490/499      0.6G   0.01166  0.006497  0.001598        22       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.933
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    491/499      0.6G   0.01372  0.006637  0.002449        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.916
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    492/499      0.6G   0.01269  0.005153  0.001612        16       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.924
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    493/499      0.6G  0.009476  0.005648  0.001543        21       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.926
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    494/499      0.6G   0.01343  0.005985   0.00171        23       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.933
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    495/499      0.6G   0.01371  0.004897  0.001537        17       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.924
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    496/499      0.6G   0.01514  0.005702  0.003928        18       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.924
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    497/499      0.6G   0.01364  0.006739  0.001754        24       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.922
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    498/499      0.6G   0.01387  0.007035  0.002672        25       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.916
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    499/499      0.6G   0.01225  0.006999   0.00163        24       320: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10       0.99          1      0.995      0.916
#
# 500 epochs completed in 0.036 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 14.4MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         10         10      0.988          1      0.995      0.952
#                awake         10          5      0.986          1      0.995      0.948
#               drowsy         10          5      0.991          1      0.995      0.956
# Results saved to runs/train/exp2

# %% [markdown]
# # 6. Load Custom Model

# %%
# model = torch.hub.load('path/to/yolov5', 'custom', path='path/to/best.pt', source='local')  # local repo

model = torch.hub.load('/home/ali/projects/python_project/YOLO/YOLO-Drowsiness-Detection-main/yolov5', 'custom', path='yolov5/runs/train/exp/weights/last.pt', force_reload=True, source='local')
# Out:
# YOLOv5 🚀 2022-7-20 Python-3.8.10 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'drowsy.9fe95120-f891-11ec-998f-59c589613518.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 (no detections)
# Speed: 11.6ms pre-process, 4.7ms inference, 0.5ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
